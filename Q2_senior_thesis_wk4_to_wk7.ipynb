# %%
# !git clone https://github.com/mjpost/sacrebleu.git
# Out:
# Cloning into 'sacrebleu'...
# remote: Enumerating objects: 2151, done.
# remote: Counting objects: 100% (743/743), done.
# remote: Compressing objects: 100% (199/199), done.
# remote: Total 2151 (delta 594), reused 610 (delta 532), pack-reused 1408
# Receiving objects: 100% (2151/2151), 2.38 MiB | 10.27 MiB/s, done.
# Resolving deltas: 100% (1446/1446), done.

# %%
# !pip install kytea
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.9/718.9 kB 16.0 MB/s eta 0:00:00m eta 0:00:01
# ...

# %%
# !pip uninstall kytea
# Out:
# Found existing installation: kytea 0.1.9
# Uninstalling kytea-0.1.9:
#   Would remove:
#     /Users/thomaspett/Desktop/pytorch-test/env/lib/python3.10/site-packages/Mykytea.py
#     /Users/thomaspett/Desktop/pytorch-test/env/lib/python3.10/site-packages/_Mykytea.cpython-310-darwin.so
#     /Users/thomaspett/Desktop/pytorch-test/env/lib/python3.10/site-packages/kytea-0.1.9.dist-info/*
#     /Users/thomaspett/Desktop/pytorch-test/env/lib/python3.10/site-packages/kytea.dylibs/libkytea.0.dylib
# Proceed (Y/n)? ^C
# ERROR: Operation cancelled by user

# %% [markdown]
# ## Decided to use the version through brew instead

# %%
# !git clone https://github.com/Unbabel/COMET
# Out:
# Cloning into 'COMET'...
# remote: Enumerating objects: 3892, done.
# remote: Counting objects: 100% (532/532), done.
# remote: Compressing objects: 100% (157/157), done.
# remote: Total 3892 (delta 418), reused 404 (delta 375), pack-reused 3360
# Receiving objects: 100% (3892/3892), 9.81 MiB | 11.43 MiB/s, done.
# Resolving deltas: 100% (2491/2491), done.

# %%
# !git clone https://github.com/MorinoseiMorizo/jparacrawl-finetune.git
# Out:
# Cloning into 'jparacrawl-finetune'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 40 (delta 16), reused 33 (delta 12), pack-reused 0
# Receiving objects: 100% (40/40), 9.97 KiB | 3.32 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
# !git clone https://github.com/fe1ixxu/ALMA.git
# Out:
# fatal: destination path 'ALMA' already exists and is not an empty directory.

# %% [markdown]
# # Sacrebleu Settings for Different Models

# %% [markdown]
# ## WMT 2023 Sacrebleu settings

# %% [markdown]
# ![Screenshot 2024-02-07 at 9.59.52 PM.png](attachment:ad34c861-c03c-47ba-9071-cb39cf4d895c.png)

# %% [markdown]
# ## WMT 2022 SOTA for different languages

# %% [markdown]
# ![image.png](attachment:6c400bd2-ce69-4950-9cd3-f016219c71fd.png)

# %% [markdown]
# ## MTNT Sacrebleu settings

# %% [markdown]
# ![image.png](attachment:e8c47fcb-f8e3-49fa-b140-7ab31baed7c0.png)

# %% [markdown]
# ## NLLB Sacrebleu settings

# %% [markdown]
# ![image.png](attachment:0157c080-e3e3-4e4e-98cd-35e9b89ca600.png)

# %% [markdown]
# ![image.png](attachment:caafc013-0f80-44b6-bc94-1cc89c9da75b.png)

# %% [markdown]
# ## NLLB Results on Flores-200 dataset

# %% [markdown]
# ![image.png](attachment:0d6615a1-1078-4ce6-b39e-87cdcd10ce2b.png)

# %% [markdown]
# ## M4T Sacrebleu Settings

# %% [markdown]
# ![image.png](attachment:40aa30d4-912f-48b0-8a1a-fdb950ad25b3.png)

# %% [markdown]
# ## M4T Results on Flores-200 dataset

# %% [markdown]
# ![image.png](attachment:b8a0e067-a642-474f-ac4c-46b747c93936.png)

# %% [markdown]
# # What Training Data Sources Used (to avoid testing on training data )

# %% [markdown]
# ## ALMA

# %% [markdown]
# ### Monolingual Finetuning Data
# - OSCAR multilingual scraped dataset
# ![image.png](attachment:bdc1989e-d828-433a-b29f-33fb6c3ed5dd.png)

# %% [markdown]
# ### Parallel Finetuning Data
# - WMT17 to WMT20 Test Data
# - FLORES 200 Test sets
# ![image.png](attachment:440d16cc-eac9-4ba3-882d-ee27c86ec9fc.png)

# %% [markdown]
# ## ALMA-R

# %% [markdown]
# - CPO Triplet Assembled with FLORES 200, GPT-4 Translated equivalent, and AlMA-LORA translated equivalent
# ![image.png](attachment:054efb26-1925-4c02-8959-a392b7143981.png)

# %% [markdown]
# ## NLLB, SeamlessM4TV1, and SeamlessM4TV2

# %% [markdown]
# ### NLLB
# - Uses FLORES 200
# ![image.png](attachment:6c486b38-6b58-43fe-94e1-f7609e993620.png)
# ### SeamlessM4Tv1
# - Uses FLORES 200 Capped at about 100 languages
# - Leverages an additional 75m bitexts, but only in extremely high resource languages
# ![image.png](attachment:ebdd196f-cb09-4faa-8c29-7d9af41ba730.png)
# ### SeamlessM4Tv2
# - Seams to be the same as v1
