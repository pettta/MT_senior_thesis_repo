# %%
# !git clone https://github.com/mjpost/sacrebleu.git
# Out:
# Cloning into 'sacrebleu'...
# remote: Enumerating objects: 2151, done.
# remote: Counting objects: 100% (743/743), done.
# remote: Compressing objects: 100% (199/199), done.
# remote: Total 2151 (delta 594), reused 610 (delta 532), pack-reused 1408
# Receiving objects: 100% (2151/2151), 2.38 MiB | 10.27 MiB/s, done.
# Resolving deltas: 100% (1446/1446), done.

# %%
# !pip install kytea
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.9/718.9 kB 16.0 MB/s eta 0:00:00m eta 0:00:01
# ...

# %% [markdown]
# # WMT 2023 Sacrebleu settings

# %% [markdown]
# ![Screenshot 2024-02-07 at 9.59.52 PM.png](attachment:ad34c861-c03c-47ba-9071-cb39cf4d895c.png)

# %% [markdown]
# ## WMT 2022 SOTA for different languages

# %% [markdown]
# ![image.png](attachment:6c400bd2-ce69-4950-9cd3-f016219c71fd.png)

# %% [markdown]
# # MTNT Sacrebleu settings

# %% [markdown]
# ![image.png](attachment:e8c47fcb-f8e3-49fa-b140-7ab31baed7c0.png)

# %% [markdown]
# # NLLB Sacrebleu settings

# %% [markdown]
# ![image.png](attachment:0157c080-e3e3-4e4e-98cd-35e9b89ca600.png)

# %% [markdown]
# ![image.png](attachment:caafc013-0f80-44b6-bc94-1cc89c9da75b.png)

# %% [markdown]
# ## NLLB Results on Flores-200 dataset

# %% [markdown]
# ![image.png](attachment:0d6615a1-1078-4ce6-b39e-87cdcd10ce2b.png)

# %% [markdown]
# # M4T Sacrebleu Settings

# %% [markdown]
# ![image.png](attachment:40aa30d4-912f-48b0-8a1a-fdb950ad25b3.png)

# %% [markdown]
# ## M4T Results on Flores-200 dataset

# %% [markdown]
# ![image.png](attachment:b8a0e067-a642-474f-ac4c-46b747c93936.png)
